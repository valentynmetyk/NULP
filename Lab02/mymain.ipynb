# %%
import numpy as np
import time
import random
import tracemalloc
import matplotlib.pyplot as plt

def reverse_array(array):
    return array[::-1]

def bubble_sort(array):
    for i in range(len(array) - 1):
        for j in range(len(array) - i - 1):
            if array[j] > array[j + 1]:
                array[j], array[j + 1] = array[j + 1], array[j]
    return array

def insertion_sort(array):
    for i in range(1, len(array)):
        current_element = array[i]
        j = i - 1
        while j >= 0 and array[j] > current_element:
            array[j + 1] = array[j]
            j -= 1
        array[j + 1] = current_element
    return array

def quick_sort(array):
    if len(array) <= 1:
        return array
    else:
        pivot = array[0]
        left = [x for x in array[1:] if x < pivot]
        right = [x for x in array[1:] if x >= pivot]
        return quick_sort(left) + [pivot] + quick_sort(right)

def binary_search(array):
    low = 0
    high = len(array) - 1
    mid = 0
    value = random.choice(array.copy())

    while low <= high:
        mid = (low + high) // 2
        if array[mid] == value:
            return mid
        elif array[mid] < value:
            low = mid + 1
        else:
            high = mid - 1

    return -1

# %%
arrayInt10 = np.random.randint(0, 10, 10).tolist()
arrayInt100 = np.random.randint(0, 100, 100).tolist()
arrayInt1000 = np.random.randint(0, 1000, 1000).tolist()


arrayFloat10 = np.random.uniform(0.0, 10.0, 10).tolist()
arrayFloat100 = np.random.uniform(0.0, 100.0, 100).tolist()
arrayFloat1000 = np.random.uniform(0.0, 1000.0, 1000).tolist()


arrays = [
    ("Int10", arrayInt10),
    ("Int100", arrayInt100),
    ("Int1000", arrayInt1000),
    ("Float10", arrayFloat10),
    ("Float100", arrayFloat100),
    ("Float1000", arrayFloat1000)
]

algs = [
    reverse_array,
    bubble_sort,
    insertion_sort,
    quick_sort,
    binary_search
]

# %%
results = {}

# Кількість повторень для більш точного вимірювання часу
repetitions = 5

for name, array in arrays:
    results[name] = {}
    for alg in algs:
        total_time = 0
        total_memory = 0
        for _ in range(repetitions):
            array_copy = array.copy()
            tracemalloc.start()
            start_time = time.perf_counter()
            if alg == binary_search:
                sorted_array = quick_sort(array_copy)  # Binary search requires sorted array
                alg(sorted_array)
            else:
                alg(array_copy.copy())
            end_time = time.perf_counter()
            current, peak = tracemalloc.get_traced_memory()
            tracemalloc.stop()
            total_time += (end_time - start_time)
            total_memory += (peak - current)
        
        avg_time = total_time / repetitions
        avg_memory = total_memory / repetitions
        
        results[name][alg.__name__] = {
            "time": avg_time,
            "memory": avg_memory
        }

        print(f"{name} with {alg.__name__}: Time = {results[name][alg.__name__]['time']}, Memory = {results[name][alg.__name__]['memory']}")
# Out:
# Int10 with reverse_array: Time = 3.088004887104034e-05, Memory = 160.0
# Int10 with bubble_sort: Time = 0.00012331996113061904, Memory = 192.0
# Int10 with insertion_sort: Time = 7.571997120976448e-05, Memory = 160.0
# Int10 with quick_sort: Time = 0.00021452000364661217, Memory = 425.6
# Int10 with binary_search: Time = 0.0005363600328564643, Memory = 248.0
# Int100 with reverse_array: Time = 1.2619933113455772e-05, Memory = 1600.0
# Int100 with bubble_sort: Time = 0.0024733599741011856, Memory = 965.0
# Int100 with insertion_sort: Time = 0.0016192199662327766, Memory = 880.0
# Int100 with quick_sort: Time = 0.0026484000496566295, Memory = 5192.0
# Int100 with binary_search: Time = 0.0027086999733000995, Memory = 3492.2
# Int1000 with reverse_array: Time = 6.137997843325138e-05, Memory = 16000.0
# Int1000 with bubble_sort: Time = 2.7055214199703186, Memory = 9087.0
# Int1000 with insertion_sort: Time = 0.9095351000316441, Memory = 8699.0
# Int1000 with quick_sort: Time = 0.014959000004455447, Memory = 55138.0
# Int1000 with binary_search: Time = 0.014661560067906976, Memory = 39232.0
# Int10000 with reverse_array: Time = 0.00011825994588434696, Memory = 160000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 19
#      17     alg(sorted_array)
#      18 else:
# ---> 19     alg(array_copy.copy())
#      20 end_time = time.perf_counter()
#      21 current, peak = tracemalloc.get_traced_memory()
#
# Cell In[1], line 13, in bubble_sort(array)
#      11 for i in range(len(array) - 1):
#      12     for j in range(len(array) - i - 1):
# ---> 13         if array[j] > array[j + 1]:
#      14             array[j], array[j + 1] = array[j + 1], array[j]
#      15 return array
#
# KeyboardInterrupt:

# %%
# Time comparison graph with logarithmic scale
plt.figure(figsize=(14, 8))

for alg in algs:
    times = [results[name][alg.__name__]["time"] for name, _ in arrays]
    plt.plot([name for name, _ in arrays], times, label=alg.__name__)

plt.xlabel("Array Type")
plt.ylabel("Time (seconds)")
plt.yscale('log')
plt.title("Time Comparison Between Different Algorithms and Array Types (Log Scale)")
plt.legend()
plt.show()

# Memory comparison graph with logarithmic scale
plt.figure(figsize=(14, 8))

for alg in algs:
    memories = [results[name][alg.__name__]["memory"] for name, _ in arrays]
    plt.plot([name for name, _ in arrays], memories, label=alg.__name__)

plt.xlabel("Array Type")
plt.ylabel("Memory (bytes)")
plt.yscale('log')
plt.title("Memory Comparison Between Different Algorithms and Array Types (Log Scale)")
plt.legend()
plt.show()

# %%
import pandas as pd

# Створюємо пустий DataFrame
df = pd.DataFrame(columns=["Array Type", "Algorithm", "Time (seconds)", "Memory (bytes)"])

# Збираємо всі дані у список словників
data = []
for name, array in arrays:
    for alg in algs:
        data.append({
            "Array Type": name,
            "Algorithm": alg.__name__,
            "Time (seconds)": results[name][alg.__name__]["time"],
            "Memory (bytes)": results[name][alg.__name__]["memory"]
        })

# Конвертуємо список словників у DataFrame
df = pd.DataFrame(data)

# Виводимо таблицю
print(df)
# Out:
#     Array Type       Algorithm  Time (seconds)  Memory (bytes)
# 0        Int10   reverse_array        0.000006           160.0
# 1        Int10     bubble_sort        0.000014           192.0
# 2        Int10  insertion_sort        0.000004           160.0
# 3        Int10      quick_sort        0.000035           625.6
# 4        Int10   binary_search        0.000034           428.8
# 5       Int100   reverse_array        0.000002          1600.0
# 6       Int100     bubble_sort        0.000388           912.0
# 7       Int100  insertion_sort        0.000128           880.0
# 8       Int100      quick_sort        0.000323          5739.2
# 9       Int100   binary_search        0.000335          4144.0
# 10     Int1000   reverse_array        0.000010         16000.0
# 11     Int1000     bubble_sort        0.487539          9132.8
# 12     Int1000  insertion_sort        0.177162          8649.2
# 13     Int1000      quick_sort        0.003563         42341.2
# 14     Int1000   binary_search        0.003819         26440.0
# 15    Int10000   reverse_array        0.000059        160000.0
# 16    Int10000     bubble_sort       71.683908         80934.8
# 17    Int10000  insertion_sort       22.971254         81079.0
# 18    Int10000      quick_sort        0.036991        595304.0
# 19    Int10000   binary_search        0.037523        435304.0
# 20     Float10   reverse_array        0.000002           160.0
# 21     Float10     bubble_sort        0.000013           192.0
# 22     Float10  insertion_sort        0.000004           160.0
# 23     Float10      quick_sort        0.000030           496.0
# 24     Float10   binary_search        0.000035           336.0
# 25    Float100   reverse_array        0.000002          1600.0
# 26    Float100     bubble_sort        0.000305           912.0
# 27    Float100  insertion_sort        0.000104           880.0
# 28    Float100      quick_sort        0.000301          4384.0
# 29    Float100   binary_search        0.000292          2784.0
# 30   Float1000   reverse_array        0.000006         16000.0
# 31   Float1000     bubble_sort        0.446937          9197.0
# 32   Float1000  insertion_sort        0.176704          8659.8
# 33   Float1000      quick_sort        0.003281         51152.0
# 34   Float1000   binary_search        0.003360         35040.4
# 35  Float10000   reverse_array        0.000037        160000.0
# 36  Float10000     bubble_sort       70.174174         81133.6
# 37  Float10000  insertion_sort       31.665344         81089.2
# 38  Float10000      quick_sort        0.059802        446688.8
# 39  Float10000   binary_search        0.058964        287534.6
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
